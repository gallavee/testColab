# %%
from google.colab import drive
drive.mount('gdrive')

import sys
sys.path.append('gdrive/My Drive/testColab')
# %cd "gdrive/My Drive/testColab"
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).
# /content/gdrive/My Drive/testColab

# %%
import pandas as pd

# %%
import fastai

# %%
from gal import hi

# %%
hi()
# Out:
# hi gal...

# %%
# !git commit -a -m"some changes"
# Out:
# [master 49349f7] some changes
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite first colab.ipynb (63%)

# %%
# !git push --set-upstream origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git add first\ colab.ipynb

# %%
 # !git config --global user.name "gal"

# %%
 # !git config --global user.email "gal@example.com"

# %%
# !git push --set-upstream origin master
# Out:
# To https://github.com/gallavee/testColab.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://1242f6ec9fa16f5c16c15a3227edacaeb9533f45@github.com/gallavee/testColab.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git remote -v
# Out:
# origin	https://429d6eed3d491ef0bfce52b6222f7022df2fd9e1@github.com/gallavee/testColab.git (fetch)
# origin	https://429d6eed3d491ef0bfce52b6222f7022df2fd9e1@github.com/gallavee/testColab.git (push)

# %%
# !git remote add origin https://1242f6ec9fa16f5c16c15a3227edacaeb9533f45@github.com/gallavee/testColab.git

# %%
# !git remote remove origin

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/testColab

# %%
# !git status

# %%
# !git branch --set-upstream-to=origin/master master
# Out:
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git
# Out:
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !wget github.com
# Out:
# --2020-01-20 21:04:55--  http://github.com/
# Resolving github.com (github.com)... 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.112|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/ [following]
# --2020-01-20 21:04:55--  https://github.com/
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1            [ <=>                ] 123.21K  --.-KB/s    in 0.03s
#
# 2020-01-20 21:04:55 (3.45 MB/s) - ‘index.html.1’ saved [126170]

# %%
# !ls
# Out:
# 'first colab.ipynb'   index.html     __pycache__
#  gal.py		      index.html.1   README.md
