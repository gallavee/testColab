# %%
from google.colab import drive
drive.mount('gdrive')

import sys
sys.path.append('gdrive/My Drive/testColab')
# %cd "gdrive/My Drive/testColab"
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).
# /content/gdrive/My Drive/testColab

# %%
import pandas as pd

# %%
import fastai

# %%
from gal import hi

# %%
hi()
# Out:
# hi gal...

# %%
# !git commit -a -m"some changes"
# Out:
# [master 02032e2] some changes
#  1 file changed, 1 insertion(+)
#  create mode 100644 first colab.ipynb

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.93 KiB | 396.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/gallavee/testColab.git
#    2b08a5d..02032e2  master -> master

# %%
# !git add first\ colab.ipynb

# %%
 # !git config --global user.name "gal"

# %%
 # !git config --global user.email "gal@example.com"

# %%
# !git push --set-upstream origin master
# Out:
# Counting objects: 2, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 213 bytes | 106.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/gallavee/testColab.git
#    da350e3..2b08a5d  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git remote -v
# Out:
# origin	https://github.com/gallavee/testColab.git (fetch)
# origin	https://github.com/gallavee/testColab.git (push)

# %%
# !git remote add origin https://429d6eed3d491ef0bfce52b6222f7022df2fd9e1@github.com/gallavee/testColab.git

# %%
# !git remote remove origin
